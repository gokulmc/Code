# %%
import numpy as np
X = np.random.random((300,5))

# %%
print X
# Out:
# [[ 0.41354469  0.98154462  0.59190188  0.99598216  0.6375562 ]
#  [ 0.68636033  0.48323934  0.57010005  0.58327713  0.64774772]
#  [ 0.59246885  0.93204162  0.63934421  0.42675707  0.75206679]
#  ...,
#  [ 0.8805314   0.5090717   0.44085767  0.95096841  0.58855173]
#  [ 0.72344557  0.33851998  0.66239289  0.82315384  0.51337684]
#  [ 0.20333025  0.64528816  0.07556221  0.64738503  0.00289936]]

# %%
pylab
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)

# %%
plt.plot(x, np.sin(x))

# %%
for i in range(1000):
    x = np.random.normal(size=500)
    y = np.random.normal(size=500)
# plot them
    plt.scatter(x, y)

# %%
x = np.linspace(1, 12, 100)
y = x[:, np.newaxis]
print x,y
# Out:
# [  1.           1.11111111   1.22222222   1.33333333   1.44444444
#    1.55555556   1.66666667   1.77777778   1.88888889   2.           2.11111111
#    2.22222222   2.33333333   2.44444444   2.55555556   2.66666667
#    2.77777778   2.88888889   3.           3.11111111   3.22222222
#    3.33333333   3.44444444   3.55555556   3.66666667   3.77777778
#    3.88888889   4.           4.11111111   4.22222222   4.33333333
#    4.44444444   4.55555556   4.66666667   4.77777778   4.88888889   5.
#    5.11111111   5.22222222   5.33333333   5.44444444   5.55555556
#    5.66666667   5.77777778   5.88888889   6.           6.11111111
#    6.22222222   6.33333333   6.44444444   6.55555556   6.66666667
#    6.77777778   6.88888889   7.           7.11111111   7.22222222
#    7.33333333   7.44444444   7.55555556   7.66666667   7.77777778
#    7.88888889   8.           8.11111111   8.22222222   8.33333333
#    8.44444444   8.55555556   8.66666667   8.77777778   8.88888889   9.
# ...

# %%
im = y  * np.cos(y)* np.sin(x)
print im.shape
print im[1]
print y.shape
print np.sin(x).shape
# Out:
# (100, 100)
# [ 0.41481343  0.44178892  0.46331584  0.47912869  0.48903246  0.49290499
#   0.49069854  0.48244031  0.46823216  0.4482493   0.4227382   0.39201347
#   0.35645404  0.31649847  0.27263954  0.22541814  0.17541667  0.12325178
#   0.06956684  0.01502392 -0.03970428 -0.09394281 -0.14702275 -0.19828945
#  -0.24711066 -0.29288425 -0.33504571 -0.37307506 -0.40650327 -0.43491809
#  -0.45796908 -0.47537193 -0.48691203 -0.49244706 -0.49190874 -0.48530373
#  -0.47271346 -0.45429324 -0.43027022 -0.40094068 -0.36666636 -0.32786994
#  -0.2850299  -0.2386746  -0.18937573 -0.13774129 -0.08440809 -0.03003389
#   0.02471072  0.07915058  0.13261427  0.18444243  0.23399587  0.28066344
#   0.32386959  0.36308146  0.39781546  0.42764321  0.45219683  0.47117353
#   0.48433925  0.49153162  0.49266194  0.48771626  0.4767556   0.45991511
#   0.4374025   0.40949541  0.37653802  0.33893679  0.29715546  0.25170932
#   0.20315885  0.15210283  0.09917093  0.04501595 -0.00969421 -0.06428481
# ...

# %%
  plt.imshow(im)
